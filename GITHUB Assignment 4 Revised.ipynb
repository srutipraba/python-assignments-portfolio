# %%
import matplotlib.pyplot as plt
import numpy as np

def gradient_descent(f,learning_rate,initial_point):
    def deriv(f,initial_point): #estimate the derivative of the function f at base_point
        return (f(initial_point+10**(-5))-f(initial_point))/10**(-5)
    x_coords=[initial_point] #this list is where you will store the x_n's
    y_coords=[f(initial_point)] #this list is where you will store the y_n's also gotta make sure the loop 
    #is not run if x0 is very close to 0
    
    linearapprox=initial_point-learning_rate*deriv(f,initial_point)
    point=initial_point-learning_rate*deriv(f,initial_point)

    #calculates the linear approximation using the initial point, the determined learning rate and derivative using the initial point
    #the second line finds a new point using the linear approximation from before

    for i in range(100):
        x_coords.append(point) #adds the current point into the list x_coords
        y_coords.append(f(point)) #adds the current function at the point into the list y_coords
        point=point-learning_rate*deriv(f,point) #computes the lineralization
        if abs(deriv(f,point))<0.001:
            print("The derivative is",deriv(f,point))
            break
    #it is trying to find where the derivative=0, which will indicate where the miniumum is
    if abs(deriv(f,point))>=0.001:
        print("Sorry, no solution")
    # after it runs through all the points, and the derivative remains greater than/equal to 0.001, then this indicates that no miniumum was found
    plot_range=np.linspace(min(x_coords)-0.5, max(x_coords)+0.5,10000)
    function_range=[f(i) for i in plot_range]
    plt.plot(plot_range,function_range)
    plt.plot(x_coords,y_coords)
    return round(x_coords[-1],3),round(y_coords[-1],3) #rounds to 3 decimal places
#if you don't find a minimum, increase range or tell user there is no solution

def f(x):
        return x**2
learning_rate=0.5
initial_point=-10 
result=gradient_descent(f,learning_rate,initial_point)
print("The minimum is",result)
# Out:
# The derivative is 0.0
# The minimum is (-0.0, 0.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

def gradient_descent(f,learning_rate,initial_point):
    def deriv(f,initial_point): #estimate the derivative of the function f at base_point
        return (f(initial_point+10**(-5))-f(initial_point))/10**(-5)
    x_coords=[initial_point] #this list is where you will store the x_n's
    y_coords=[f(initial_point)] #this list is where you will store the y_n's also gotta make sure the loop 
    #is not run if x0 is very close to 0
    
    linearapprox=initial_point-learning_rate*deriv(f,initial_point)
    point=initial_point-learning_rate*deriv(f,initial_point)
    #calculates the linear approximation using the initial point, the determined learning rate and derivative using the initial point
    #the second line finds a new point using the linear approximation from before
    for i in range(10000):
        x_coords.append(point)
        y_coords.append(f(point))
        point=point-learning_rate*deriv(f,point)
        if abs(deriv(f,point))<0.001:
            print("The derivative is",deriv(f,point))
            break
        #it is trying to find where the derivative=0, which will indicate where the miniumum is
    if abs(deriv(f,point))>=0.001:
        print("Sorry, no solution")
        
     # after it runs through all the points, and the derivative remains greater than/equal to 0.001, then this indicates that no miniumum was found        
    plot_range=np.linspace(min(x_coords)-0.5, max(x_coords)+0.5,10000)
    function_range=[f(i) for i in plot_range]
    plt.plot(plot_range,function_range)
    plt.plot(x_coords,y_coords)
    return round(x_coords[-1],3),round(y_coords[-1],3) #rounds to 3 decimal places
#if you don't find a minimum, increase range or tell user there is no solution

def f(x):
        return -3*x**3+10*x**2-5*x-3
learning_rate=0.005
initial_point=-10 
result=gradient_descent(f,learning_rate,initial_point)
print("The minimum is",result)
# Out:
# The derivative is -0.0009829093539082123
# The minimum is (0.287, -3.682)

# %%
import matplotlib.pyplot as plt
import numpy as np

def gradient_descent(f,learning_rate,initial_point):
    def deriv(f,initial_point): #estimate the derivative of the function f at base_point
        return (f(initial_point+10**(-5))-f(initial_point))/10**(-5)
    x_coords=[initial_point] #this list is where you will store the x_n's
    y_coords=[f(initial_point)] #this list is where you will store the y_n's also gotta make sure the loop 
    #is not run if x0 is very close to 0
    
    linearapprox=initial_point-learning_rate*deriv(f,initial_point)
    point=initial_point-learning_rate*deriv(f,initial_point)
    for i in range(100000):
        x_coords.append(point)
        y_coords.append(f(point))
        point=point-learning_rate*deriv(f,point)
        if abs(deriv(f,point))<0.001:
            print("The derivative is",deriv(f,point))
            break
    if abs(deriv(f,point))>=0.001:
        print("Sorry, no solution")
            
    plot_range=np.linspace(min(x_coords)-0.5, max(x_coords)+0.5,10000)
    function_range=[f(i) for i in plot_range]
    plt.plot(plot_range,function_range)
    plt.plot(x_coords,y_coords)
    return round(x_coords[-1],3),round(y_coords[-1],3) #rounds to 3 decimal places
#if you don't find a minimum, increase range or tell user there is no solution
def f(x):
    if x>0:
        return x**x
    elif x==0:
        return 1
    else:
        return abs(x)**abs(x)
learning_rate=0.005
initial_point=0.005 
result=gradient_descent(f,learning_rate,initial_point)
print("The minimum is",result)
# Out:
# The derivative is -0.0009934799316546616
# The minimum is (0.367, 0.692)

# %%
def gradient_descent(f,learning_rate,initial_point):
    def deriv(f,initial_point): #estimate the derivative of the function f at base_point
        return (f(initial_point+10**(-5))-f(initial_point))/10**(-5)
    x_coords=[initial_point] #this list is where you will store the x_n's
    y_coords=[f(initial_point)] #this list is where you will store the y_n's also gotta make sure the loop 
    #is not run if x0 is very close to 0
    
    linearapprox=initial_point-learning_rate*deriv(f,initial_point)
    point=initial_point-learning_rate*deriv(f,initial_point)
    for i in range(100000):
        x_coords.append(point)
        y_coords.append(f(point))
        point=point-learning_rate*deriv(f,point)
        if abs(deriv(f,point))<0.001:
            print("The derivative is",deriv(f,point))
            break
    if abs(deriv(f,point))>=0.001:
        print("Sorry, no solution")
            
    plot_range=np.linspace(min(x_coords)-0.5, max(x_coords)+0.5,10000)
    function_range=[f(i) for i in plot_range]
    plt.plot(plot_range,function_range)
    plt.plot(x_coords,y_coords)
    return round(x_coords[-1],3),round(y_coords[-1],3) #rounds to 3 decimal places
#if you don't find a minimum, increase range or tell user there is no solution
def f(x):
        return abs(x)
learning_rate=0.005
initial_point=-0.005 
result=gradient_descent(f,learning_rate,initial_point)
#print("The minimum is",result)
# Out:
# Sorry, no solution
